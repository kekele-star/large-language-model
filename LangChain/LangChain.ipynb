# %%
# !pip install langchain
from langchain.document_loaders import TextLoader
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# tables 3.8.0 requires cython>=0.29.21, which is not installed.
# python-lsp-black 1.2.1 requires black>=22.3.0, but you have black 0.0 which is incompatible.
# ...
#   Obtaining dependency information for langchain from https://files.pythonhosted.org/packages/23/98/c70fac0f1b3193ced86013b563119c27c68ac26b684815f407555224108d/langchain-0.1.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for dataclasses-json<0.7,>=0.5.7 from https://files.pythonhosted.org/packages/ae/53/8c006de775834cd4ea64a445402dc195caeebb77dc76b7defb9b3887cb0d/dataclasses_json-0.6.3-py3-none-any.whl.metadata
# ...

# %%
from langchain.llms import OpenAI
from langchain.prompts import PromptTemplate
from dotenv import load_dotenv

load_dotenv()

# %%
def generate_pet_name():
    llm = OpenAI(temperature=0.7)

    prompt_template_name = PromptTemplate(
        input_variables=['animal_type'],
        template="I have a {animal_type} pet and i want a cool name for it. Suggest me five cool names for my pet."
    )

    name = llm("I have a dog pet and i want a cool name for it. Suggest me five cool for my pet ")

    response= name_chain({'animal_type': animal_type})
    return name

if __name__ == "__main__":
    print(generate_pet_name())

# %%
loader = TextLoader("nvidia_text.txt")
data = loader.load()
data[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\langchain_community\document_loaders\text.py:41, in TextLoader.load(self)
#      40 try:
# ---> 41     with open(self.file_path, encoding=self.encoding) as f:
#      42         text = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nvda_text.txt'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 2
#       1 loader = TextLoader("nvda_text.txt")
# ----> 2 data = loader.load()
#       3 data[0]
#
# File ~\anaconda3\Lib\site-packages\langchain_community\document_loaders\text.py:57, in TextLoader.load(self)
#      55         raise RuntimeError(f"Error loading {self.file_path}") from e
#      56 except Exception as e:
# ...
